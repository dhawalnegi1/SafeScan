# %%
from typing import TypedDict, Annotated
from langchain_core.agents import AgentAction
from langchain_core.messages import BaseMessage
import operator
from langchain_core.tools import tool
from serpapi import GoogleSearch
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import ToolCall, ToolMessage
from langchain_openai import ChatOpenAI
from typing import TypedDict

class AgentState(TypedDict):
   input: str
   chat_history: list[BaseMessage]
   intermediate_steps: Annotated[list[tuple[AgentAction, str]], operator.add]

@tool("product_search")
def product_search(query: str):
   """Finds general knowledge information using Google search. Can also be used
   to augment more 'general' knowledge to a previous specialist query. """
   search = GoogleSearch({
       "engine": "google",
       "api_key":  "436684e4d11e3a22274f830442d3c8643c2e4ce329122faf0fdedb35d2f8c267",
       "q": query,
       "num": 5
   })
   results = search.get_dict()["organic_results"]
   contexts = "\n---\n".join(
       ["\n".join([x["title"], x["snippet"], x["link"]]) for x in results]
   )
   return contexts

@tool("final_answer")
def final_answer(
   ingredients: str,
   allergens: str,
   harmful_ingredients: str,
   conclusion: str,
   sources: str
):
   """Returns a natural language response to the user explaining the ingredients and chemical present in the product and any allergen information and harmful effects if any of those chemicals and ingredients. There are several sections to this report, those are:
   - `Ingredients`: List of major ingredients.
   - `Allergens`: Highlight any allergens present in the product.
   - `Harmful Ingredients`: list harmful ingredients and their effects.
   - `conclusion`: this is a short single paragraph conclusion providing a
   concise but sophisticated view on what was found.
   - `sources`: a bullet point list provided detailed sources for all information
   referenced during the research process
   """
   if type(ingredients) is list:
      ingredients = "\n".join([f"- {r}" for r in ingredients])
   if type(harmful_ingredients) is list:
      allergens = "\n".join([f"- {r}" for r in harmful_ingredients])
   if type(allergens) is list:
      allergens = "\n".join([f"- {r}" for r in allergens])
   if type(sources) is list:
      sources = "\n".join([f"- {s}" for s in sources])

   return ""



system_prompt = """You are the oracle, the great AI decision maker.
Given the user's query you must identify the product and its brand from the user query and then you should use the tools available to you to find the ingredients and chemical which are presents in the product.
Then you should search for any allergen information and harmful effects if any for the chemicals and ingredients of the product. You should then summarize your finding ina report formate.There are several sections to this report, those are:

If you see that a tool has been used (in the scratchpad) with a particular
query, do NOT use that same tool with the same query again. Also, do NOT use
any tool more than four time (ie, if the tool appears in the scratchpad 4 times, do
not use it again).

Once you have collected information
to answer the user's question (stored in the scratchpad) use the final_answer
tool."""


prompt = ChatPromptTemplate.from_messages([
   ("system", system_prompt),
   MessagesPlaceholder(variable_name="chat_history"),
   ("user", "{input}"),
   ("assistant", "scratchpad: {scratchpad}"),
])


llm = ChatOpenAI(
   model="gpt-4o",
   openai_api_key="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",
   temperature=0
)


tools=[
   product_search,
   final_answer
]

def create_scratchpad(intermediate_steps: list[AgentAction]):
   research_steps = []
   for i, action in enumerate(intermediate_steps):
       if action.log != "TBD":
           # this was the ToolExecution
           research_steps.append(
               f"Tool: {action.tool}, input: {action.tool_input}\n"
               f"Output: {action.log}"
           )
   return "\n---\n".join(research_steps)


oracle = (
   {
       "input": lambda x: x["input"],
       "chat_history": lambda x: x["chat_history"],
       "scratchpad": lambda x: create_scratchpad(
           intermediate_steps=x["intermediate_steps"]
       ),
   }
   | prompt
   | llm.bind_tools(tools, tool_choice="auto")
)

# %%
def run_oracle(state: TypedDict):
   print("run_oracle")
   print(f"intermediate_steps: {state['intermediate_steps']}")
   out = oracle.invoke(state)
   tool_name = out.tool_calls[0]["name"]
   tool_args = out.tool_calls[0]["args"]
   action_out = AgentAction(
       tool=tool_name,
       tool_input=tool_args,
       log="TBD"
   )
   return {
       "intermediate_steps": [action_out]
   }


def router(state: TypedDict):
   # return the tool name to use
   if isinstance(state["intermediate_steps"], list):
       return state["intermediate_steps"][-1].tool
   else:
       # if we output bad format go to final answer
       print("Router invalid format")
       return "final_answer"

# %%
tool_str_to_func = {
   "product_search": product_search,
   "final_answer": final_answer,

}


def run_tool(state: TypedDict):
   tool_name = state["intermediate_steps"][-1].tool
   tool_args = state["intermediate_steps"][-1].tool_input
   print("run_tool")
   print(f"{tool_name}.invoke(input={tool_args})")
   # run tool
   out = tool_str_to_func[tool_name].invoke(input=tool_args)
   action_out = AgentAction(
       tool=tool_name,
       tool_input=tool_args,
       log=str(out)
   )
   return {"intermediate_steps": [action_out]}

# %%
from langgraph.graph import StateGraph, END


# initialize the graph with our AgentState
graph = StateGraph(AgentState)


# add nodes
graph.add_node("oracle", run_oracle)
graph.add_node("product_search", run_tool)
# graph.add_node("ingredients_effect_lookup", run_tool)
# graph.add_node("top_harmful_ingredients", run_tool)
# graph.add_node("allergen_ingredients", run_tool)
graph.add_node("final_answer", run_tool)



# specify the entry node
graph.set_entry_point("oracle")
graph.add_edge("final_answer", END)


# add the conditional edges which use the router
graph.add_conditional_edges(
   source="oracle",  # where in graph to start
   path=router,  # function to determine which node is called
)


# create edges from each tool back to the oracle
for tool_obj in tools:
   if tool_obj.name != "final_answer":
       graph.add_edge(tool_obj.name, "oracle")


# if anything goes to final answer, it must then move to END
graph.add_edge("final_answer", END)


# finally, we compile our graph
runnable = graph.compile()

# %%
out = runnable.invoke({
    "input": "I want to know about 'Revitalift Derm Intensives 10% Pure Glycolic Acid Serum' from L'Oreal Paris",
    "chat_history": [],
})
# Out:
# run_oracle
# intermediate_steps: []
# run_tool
# product_search.invoke(input={'query': 'Revitalift Derm Intensives 10% Pure Glycolic Acid Serum ingredients'})
# run_oracle
# intermediate_steps: [AgentAction(tool='product_search', tool_input={'query': 'Revitalift Derm Intensives 10% Pure Glycolic Acid Serum ingredients'}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 'Revitalift Derm Intensives 10% Pure Glycolic Acid Serum ingredients'}, log="Revitalift 10% Pure Glycolic Acid Serum - L'Oréal Paris\nThis daily use face serum is specially blended with Aloe - a plant-derived/botanical extract, renowned for its soothing benefits.\nhttps://www.lorealparisusa.com/skin-care/exfoliant/revitalift-derm-intensives-10-pure-glycolic-acid-serum\n---\nL'Oreal Paris Revitalift Derm Intensives 10% Pure Glycol
}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 'Revitalift Derm Intensives 10% Pure Glycolic Acid Serum allergens'}, log="Revitalift 10% Pure Glycolic Acid Serum - L'Oréal Paris\nThis serum is fragrance free, paraben free, mineral oil free, dye free, allergy tested. Products with Glycolic Acid may increase photosensitivity. Apply ...\nhttps://www.lorealparisusa.com/skin-care/exfoliant/revitalift-derm-intensives-10-pure-glycolic-acid-serum\n---\nL'Oreal Paris Revitalift Derm Intensives 10% Pure Glycolic ...\nSkinSAFE has reviewed the ingredients of L'Oreal Paris Revitalift Derm Intensives 10% Pure Glycolic Acid Face Serum and found it to be 91% Top Allergen Free and ...\nhttps://www.skinsafeproducts.com/l-oreal-paris-revitalift-derm-intensives-10-pure-glycolic-acid-face-serum\n---\nL'Oreal Paris Revitalift Derm Intensives 10% Pure Glycolic ...\nNEW Resurfacing 10% Pure Glycolic Acid Daily Serum visibly evens tone, reduces dark spots & wrinkles.\nhttps://incidecoder.com/products/loreal-paris-10-pure-glycolic-acid-serum\n---\nL'Oreal Paris Revitalift 10% Pure Glycolic Acid Face ...\nRevitalift Derm Intensives 10% Pure Glycolic Acid Serum is also formulated with Aloe – plant-derived/botanical extract, renowned for its soothing benefits.\nhttps://www.amazon.com/LOreal-Paris-Revitalift-Intensives-Corrector/dp/B07TVMFM5C\n---\nL'Oreal Paris Revitalift Derm Intensives 10% Pure Glycolic ...\nRevitalift Derm Intensives 10% Pure Glycolic Acid Serum is a daily exfoliating serum to visibly even skin tone and reduce wrinkles.\nhttps://www.cvs.com/shop/l-oreal-paris-revitalift-derm-intensives-10-pure-glycolic-acid-face-serum-prodid-349012")]
# run_tool
# final_answer.invoke(input={'ingredients': 'Aqua/Water/Eau, Glycolic Acid, Glycerin, Alcohol Denat., Sodium Hydroxide, Aloe Barbadensis Leaf Juice, Sodium Hyaluronate, Hydroxyethylcellulose, Ascorbyl Glucoside.', 'allergens': 'The product is fragrance-free, paraben-free, mineral oil-free, dye-free, and allergy tested. It is 91% top allergen-free according to SkinSAFE. However, products with Glycolic Acid may increase photosensitivity.', 'harmful_ingredients': 'Glycolic Acid, while beneficial for exfoliation, can increase photosensitivity, making the skin more susceptible to sunburn. It is advised to use sunscreen when using products containing Glycolic Acid.', 'conclusion': "The Revitalift Derm Intensives 10% Pure Glycolic Acid Serum by L'Oreal Paris is formulated with key ingredients like Glycolic Acid and Aloe Barbadensis Leaf Juice, which provide exfoliating and soothing benefits. The product is largely free from common allergens, but users should be cautious of increased photosensitivity due to Glycolic Acid. Overall, it is a well-formulated serum for those looking to improve skin texture and tone, provided sun protection is used concurrently.", 'sources': "- L'Oreal Paris official website\n- INCIDecoder\n- SkinSAFE\n- Amazon product listing\n- CVS product listing"})

# %%
def build_report(output: dict):
   return f"""
Ingredients
------------
{output["ingredients"]}


harmful_ingredients
--------------
{output["harmful_ingredients"]}


Allergens
------
{output["allergens"]}


Conclusion
------- 
{output["conclusion"]}


SOURCES
-------
{output["sources"]}
"""

# %%
print(build_report(
    output=out["intermediate_steps"][-1].tool_input
))
# Out:
# Ingredients
# ------------
# Aqua/Water/Eau, Glycolic Acid, Glycerin, Alcohol Denat., Sodium Hydroxide, Aloe Barbadensis Leaf Juice, Sodium Hyaluronate, Hydroxyethylcellulose, Ascorbyl Glucoside.
#
#
# harmful_ingredients
# --------------
# Glycolic Acid, while beneficial for exfoliation, can increase photosensitivity, making the skin more susceptible to sunburn. It is advised to use sunscreen when using products containing Glycolic Acid.
#
#
# Allergens
# ------
# The product is fragrance-free, paraben-free, mineral oil-free, dye-free, and allergy tested. It is 91% top allergen-free according to SkinSAFE. However, products with Glycolic Acid may increase photosensitivity.
#
#
# Conclusion
# -------
# The Revitalift Derm Intensives 10% Pure Glycolic Acid Serum by L'Oreal Paris is formulated with key ingredients like Glycolic Acid and Aloe Barbadensis Leaf Juice, which provide exfoliating and soothing benefits. The product is largely free from common allergens, but users should be cautious of increased photosensitivity due to Glycolic Acid. Overall, it is a well-formulated serum for those looking to improve skin texture and tone, provided sun protection is used concurrently.
#
#
# SOURCES
# -------
# - L'Oreal Paris official website
# - INCIDecoder
# - SkinSAFE
# - Amazon product listing
# - CVS product listing

# %%
out = runnable.invoke({
    "input": "I want to know about 'Lash sensational Luscious Mascara' from Maybelline",
    "chat_history": [],
})
print(build_report(
    output=out["intermediate_steps"][-1].tool_input
))
# Out:
# run_oracle
# intermediate_steps: []
# run_tool
# product_search.invoke(input={'query': 'Lash Sensational Luscious Mascara Maybelline ingredients'})
# run_oracle
# intermediate_steps: [AgentAction(tool='product_search', tool_input={'query': 'Lash Sensational Luscious Mascara Maybelline ingredients'}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 'Lash Sensational Luscious Mascara Maybelline ingredients'}, log='Lash Sensational® Luscious Washable Mascara\nLash Sensational Luscious is formulated with a blend of 3 precious oils - Rose Oil, Safflower Oil and Argon Oil - That help reduce mascara brittleness while ...\nhttps://www.maybelline.com/eye-makeup/mascara/lash-sensational-luscious-washable-mascara\n---\nLash Sensational® Luscious Waterproof Mascara\nLash Sensational Luscious is formulated with a blend of 3 precious oils - Rose Oil, Safflower Oil and Argon Oil - That help reduce mascara brittleness.\nhttps://www.maybelline.com/eye-makeup/mascara/lash-sensational-luscious-waterproof-mascara\n---\nBlackest Black Lash Sensational Luscious Mascara | Ulta ...\nFree Shipping at $35. Shop Blackest Black Lash Sensational Luscious Mascara Maybelline. ... Ingredients. Aqua / Water / Eau, Paraffin, Cera Alba / Beeswax / Cire ...\nhttps://www.ulta.com/p/lash-sensational-luscious-mascara-xlsImpprod13501061?sku=2295320\n---\nMaybelline Lash Sensational Luscious Washable Mascara\nMaybelline Lash Sensational Luscious Washable Mascara, Blackest Black, G684392 1. Ingredients: Aqua / Water / Eau, Paraffin, Cera Alba / Beeswax / Cire Dabeille ...\nhttps://www.cvs.com/shop/ingredients/maybelline-lash-sensational-luscious-washable-mascara-prodid-1016287\n---\nMaybelline Lash Sensational Luscious Waterproof Mascara\nIngredients for Maybelline Lash Sensational Luscious Waterproof Mascara · Reviews for Maybelline Lash Sensational Luscious Waterproof Mascara. *Customer ...\nhttps://www.cvs.com/shop/maybelline-lash-sensational-luscious-waterproof-mascara-prodid-1016357')]
# run_tool
# product_search.invoke(input={'query': 'Lash Sensational Luscious Mascara Maybelline allergens'})
# run_oracle
# intermediate_steps: [AgentAction(tool='product_search', tool_input={'query': 'Lash Sensational Luscious Mascara Maybelline ingredients'}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': '
# run_tool
# final_answer.invoke(input={'ingredients': 'Aqua / Water / Eau, Paraffin, Cera Alba / Beeswax / Cire Dabeille, Rose Oil, Safflower Oil, Argon Oil.', 'allergens': 'The product is 82% Top Allergen Free and free of Gluten, Coconut, and Nickel.', 'harmful_ingredients': 'No specific harmful ingredients were identified in the sources reviewed.', 'conclusion': 'Lash Sensational Luscious Mascara by Maybelline is formulated with a blend of oils and waxes, including Rose Oil, Safflower Oil, and Argon Oil, which help reduce brittleness. It is largely free from common allergens, making it suitable for most users. No harmful ingredients were identified, suggesting it is a safe choice for regular use.', 'sources': '- https://www.maybelline.com/eye-makeup/mascara/lash-sensational-luscious-washable-mascara\n- https://www.ulta.com/p/lash-sensational-luscious-mascara-xlsImpprod13501061?sku=2295320\n- https://www.skinsafeproducts.com/maybelline-new-york-lash-sensational-luscious-mascara-waterproof-704-very-black-0-3-fl-oz-9-0-ml'})
#
# Ingredients
# ------------
# Aqua / Water / Eau, Paraffin, Cera Alba / Beeswax / Cire Dabeille, Rose Oil, Safflower Oil, Argon Oil.
#
#
# harmful_ingredients
# --------------
# No specific harmful ingredients were identified in the sources reviewed.
#
#
# Allergens
# ------
# The product is 82% Top Allergen Free and free of Gluten, Coconut, and Nickel.
#
#
# Conclusion
# -------
# Lash Sensational Luscious Mascara by Maybelline is formulated with a blend of oils and waxes, including Rose Oil, Safflower Oil, and Argon Oil, which help reduce brittleness. It is largely free from common allergens, making it suitable for most users. No harmful ingredients were identified, suggesting it is a safe choice for regular use.
#
#
# SOURCES
# -------
# - https://www.maybelline.com/eye-makeup/mascara/lash-sensational-luscious-washable-mascara
# - https://www.ulta.com/p/lash-sensational-luscious-mascara-xlsImpprod13501061?sku=2295320
# - https://www.skinsafeproducts.com/maybelline-new-york-lash-sensational-luscious-mascara-waterproof-704-very-black-0-3-fl-oz-9-0-ml

# %%
out = runnable.invoke({
    "input": "I want to know about 'Nail Tek Mosturizing Strengthener 4' from Nail Tek",
    "chat_history": [],
})
print(build_report(
    output=out["intermediate_steps"][-1].tool_input
))
# Out:
# run_oracle
# intermediate_steps: []
# run_tool
# product_search.invoke(input={'query': 'Nail Tek Moisturizing Strengthener 4 ingredients'})
# run_oracle
# intermediate_steps: [AgentAction(tool='product_search', tool_input={'query': 'Nail Tek Moisturizing Strengthener 4 ingredients'}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 'Nail Tek Moisturizing Strengthener 4 ingredients'}, log='Nail Tek Moisturizing Strengthener 4 Ingredients\nNail Tek Moisturizing Strengthener 4 Ingredients: Ethyl Acetate, Alcohol Denat., Butyl Acetate, Nitrocellulose, Tosylamide/Formaldehyde Resin, Acrylates ...\nhttps://www.cvs.com/shop/ingredients/nail-tek-moisturizing-strengthener-4-prodid-405295\n---\nstrengthener - formula 4\nKey Ingredients: Hydrolyzed Wheat Protein - effective moisture binding capabilities; Vitamin B5 - regulates hydration (water retention) and improves flexibility.\nhttps://www.nailtek.com/strengthener-formula-4.html?srsltid=AfmBOorMe_RPQnXEq-iWwSqshvF_ZmXr8A7GqYVoxybVBMQvtXFKegqM\n---\nNail Tek Moisturizing Strengthener 4\nIngredients for Nail Tek Moisturizing Strengthener 4 · Reviews for Nail Tek Moisturizing Strengthener 4. *Customer reviews and ratings solely reflect the views ...\nhttps://www.cvs.com/shop/nail-tek-moisturizing-strengthener-4-prodid-405295')]
# run_tool
# product_search.invoke(input={'query': 'Nail Tek Moisturizing Strengthener 4 allergens'})
# run_oracle
# intermediate_steps: [AgentAction(tool='product_search', tool_input={'query': 'Nail Tek Moisturizing Strengthener 4 ingredients'}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 'Nail Tek Moisturizing Strengthener 4
}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 'Nail Tek Moisturizing Strengthener 4 harmful effects'}, log="Nail Tek Moisturizing Strengthener 4, 0.5 oz\nWARNING: THIS PRODUCT CAN EXPOSE YOU TO CHEMICALS INCLUDING FORMALDEHYDE, WHICH ARE KNOWN TO THE STATE OF CALIFORNIA TO CAUSE CANCER. FOR MORE INFORMATION GO TO ...\nhttps://www.nailtek.com/nail-tek-moisturizing-strengthener-4-0-5-oz.html?srsltid=AfmBOorkWLxg8KBeKAnKBdQlzBgiDjNQU8wLZ6KepAhY4iEJ0qNua8VI\n---\nHas anyone had nail tek make their nails worse?\nYes. I did nail tek 4 and it made my nails so much worse. Peeling, weak, thin as hell. I've heard the issue with any hardeners/strengtheners is that they don't ...\nhttps://www.reddit.com/r/RedditLaqueristas/comments/jwmto8/has_anyone_had_nail_tek_make_their_nails_worse/\n---\nEWG Skin Deep® | Nail Tek for Hard Brittle ...\nIngredient concerns · MODERATE. Cancer · HIGH. Allergies & Immu ...
# run_tool
# final_answer.invoke(input={'ingredients': 'Ethyl Acetate, Alcohol Denat., Butyl Acetate, Nitrocellulose, Tosylamide/Formaldehyde Resin, Acrylates, Hydrolyzed Wheat Protein, Vitamin B5, Pentavitin.', 'allergens': "The product is 73% top allergen-free and is free of gluten, coconut, nickel, lanolin, talc, and paraben. However, it contains formaldehyde, which is a known allergen and can cause cancer as per California's Proposition 65.", 'harmful_ingredients': 'Formaldehyde is present in the product, which is known to cause cancer. It also has moderate concerns for allergies and immunotoxicity, and developmental and reproductive toxicity.', 'conclusion': 'Nail Tek Moisturizing Strengthener 4 contains several beneficial ingredients like Hydrolyzed Wheat Protein and Vitamin B5 for nail hydration and strength. However, it also contains formaldehyde, a chemical with significant health concerns, including cancer risk. Users should weigh the benefits against the potential risks, especially if they have sensitivities or concerns about formaldehyde exposure.', 'sources': '- https://www.cvs.com/shop/ingredients/nail-tek-moisturizing-strengthener-4-prodid-405295\n- https://www.nailtek.com/strengthener-formula-4.html\n- https://www.skinsafeproducts.com/nail-tek-4-moisturizing-strengthener-hydrate-0-5-oz-15-ml\n- https://www.nailtek.com/nail-tek-moisturizing-strengthener-4-0-5-oz.html\n- https://www.ewg.org/skindeep/products/852754-Nail_Tek_for_Hard_Brittle_Nails_Strengthener_2019_formulation/'})
#
# Ingredients
# ------------
# Ethyl Acetate, Alcohol Denat., Butyl Acetate, Nitrocellulose, Tosylamide/Formaldehyde Resin, Acrylates, Hydrolyzed Wheat Protein, Vitamin B5, Pentavitin.
#
#
# harmful_ingredients
# --------------
# Formaldehyde is present in the product, which is known to cause cancer. It also has moderate concerns for allergies and immunotoxicity, and developmental and reproductive toxicity.
#
#
# Allergens
# ------
# The product is 73% top allergen-free and is free of gluten, coconut, nickel, lanolin, talc, and paraben. However, it contains formaldehyde, which is a known allergen and can cause cancer as per California's Proposition 65.
#
#
# Conclusion
# -------
# Nail Tek Moisturizing Strengthener 4 contains several beneficial ingredients like Hydrolyzed Wheat Protein and Vitamin B5 for nail hydration and strength. However, it also contains formaldehyde, a chemical with significant health concerns, including cancer risk. Users should weigh the benefits against the potential risks, especially if they have sensitivities or concerns about formaldehyde exposure.
#
#
# SOURCES
# -------
# - https://www.cvs.com/shop/ingredients/nail-tek-moisturizing-strengthener-4-prodid-405295
# - https://www.nailtek.com/strengthener-formula-4.html
# - https://www.skinsafeproducts.com/nail-tek-4-moisturizing-strengthener-hydrate-0-5-oz-15-ml
# - https://www.nailtek.com/nail-tek-moisturizing-strengthener-4-0-5-oz.html
# - https://www.ewg.org/skindeep/products/852754-Nail_Tek_for_Hard_Brittle_Nails_Strengthener_2019_formulation/

# %%
out = runnable.invoke({
    "input": "I want to know about 'Advil' from Pfizer",
    "chat_history": [],
})
print(build_report(
    output=out["intermediate_steps"][-1].tool_input
))
# Out:
# run_oracle
# intermediate_steps: []
# run_tool
# product_search.invoke(input={'query': 'Advil Pfizer ingredients'})
# run_oracle
# intermediate_steps: [AgentAction(tool='product_search', tool_input={'query': 'Advil Pfizer ingredients'}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 'Advil Pfizer ingredients'}, log='Advil (Ibuprofen) Tablets for Pain Relief\nIngredients. Active ingredient: 200 mg Ibuprofen (NSAID)* *Nonsteroidal anti-inflammatory drug.\nhttps://www.advil.com/our-products/advil-pain/advil-tablets/\n---\nLabel: Advil- ibuprofen tablet, coated\nActive Ingredient: Advil Tablets (in each tablet) Ibuprofen 200 mg (NSAID)* *nonsteroidal anti-inflammatory drug - Advil Caplets (in each caplet) Ibuprofen 200 ...\nhttps://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=1a665e64-9f30-be37-4a83-38789f1f1e89\n---\nAdvil Liqui-Gels: Dosage & Ingredients\nActive ingredient: Solubilized ibuprofen equal to 200 mg ibuprofen (NSAID)* (present as the free acid and potassium salt) *Nonsteroidal anti-inflammatory drug.\nhttps://www.advil.com/our-products/advil-pain/advil-liqui-gels/\n---\nLabel: Advil: ibuprofen tablet coated\nActive ingredient (in each tablet) Ibuprofen 200 mg (NSAID) 1 - 1 - nonsteroidal anti-inflammatory drug Purpose Pain reliever/Fever reducer\nhttps://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=772360bd-8631-4d24-b4db-5a7e6e1d9a13\n---\nAdvil Migraine\nActive ingredient (in each brown oval capsule). Purpose. Solubilized ibuprofen equal to 200 mg ibuprofen (NSAID)* ………..…………..Pain reliever. (present as the ...\nhttps://labeling.pfizer.com/ShowLabeling.aspx?id=2580')]
# run_tool
# product_search.invoke(input={'query': 'Advil Pfizer allergens'})
# run_oracle
# intermediate_steps: [AgentAction(tool='product_search', tool_input={'query': 'Advil Pfizer ingredients'}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 'Advil Pfizer ingredients'}, log='Advil (Ibuprofen) Tablets for Pain Relief\nIngredients. Active ingredient: 200 mg Ibuprofen (NSAID)* *Nonsteroidal anti-inflammatory drug.\nhttps://www.advil.com/our-products/advil-pain/advil-tablets/\n---\nLabel: Advil- ibuprofen tablet, coated\nActive Ingredient: Advil Tablets (in each tablet) Ibuprofen 200 mg (NSAID)* *nonsteroidal anti-inflammatory drug - Advil Caplets (in each caplet) Ibuprofen 200 ...\nhttps://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=1a665e64-9f30-be37-4a83-38789f1f1e89\n---\nAdvil Liqui-Gels: Dosage & Ingredients\nActive ingredient: Solubilized ibuprofen equal to 200 mg ibuprofen (NSAID)* (present as the free acid and potassium salt) *Nonsteroidal anti-inflammatory drug.\nhttps://www.advil.com/our-products/advil-pain/advil-liqui-gels/\n---\nLabel: Advil: ibuprofen tablet coated\nActive ingredient (in each tablet) Ibuprofen 200 mg (NSAID) 1 - 1 - nonsteroidal anti-inflammatory drug Purpose Pain reliever/Fever reducer\nhttps://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=772360bd-8631-4d24-b4db-5a7e6e1d9a13\n---\nAdvil Migraine\nActive ingredient (in each brown oval capsule). Purpose. Solubilized ibuprofen equal to 200 mg ibuprofen (NSAID)* ………..…………..Pain reliever. (present as the ...\nhttps://labeling.pfizer.com/ShowLabeling.aspx?id=2580'), AgentAction(tool='product_search', tool_input={'query': 'Advil Pfizer allergens'}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 'Advil Pfizer allergens'}, log='Advil ® Tablets\nAllergy alert Ibuprofen may cause a severe allergic reaction, especially in people allergic to aspirin. Symptoms may include: hives.\nhttps://dailymed.nlm.nih.gov/dailymed/fda/fdaDrugXsl.cfm?setid=772360bd-8631-4d24-b4db-5a7e6e1d9a13&type=display\n---\nAdvil Migraine\nAllergy alert: Ibuprofen may cause a severe allergic reaction, especially in people allergic to aspirin. Symptoms may include: ▫ hives. ▫ facial swelling.\nhttps://labeling.pfizer.com/ShowLabeling.aspx?id=2580\n---\nLabel: ADVIL ALLERGY CONGESTION RELIEF\nAllergy alert - Ibuprofen may cause a severe allergic reaction, especially in people allergic to aspirin. Symptoms may include: hives - facial swelling - asthma ...\nhttps://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=883fcccb-cc1b-4b31-9649-771264546b13\n---\nAdvil Liqui-Gels\nAllergy alert: Ibuprofen may cause a severe allergic reaction, especially in people allergic to aspirin. Symptoms may include: □ hives.\nhttps://www.accessdata.fda.gov/drugsatfda_docs/label/2017/020402s042lbl.pdf\n---\nAdvil (Ibuprofen) Tablets for Pain Relief\nThis product contains ibuprofen, which may cause allergic reaction, especially in those allergic to aspirin. This product contains an NSAID, which may cause ...\nhttps://www.advil.com/our-products/advil-pain/advil-tablets/')]
# run_tool
# final_answer.invoke(input={'ingredients': 'The primary active ingredient in Advil is Ibuprofen, which is a nonsteroidal anti-inflammatory drug (NSAID). Each tablet contains 200 mg of Ibuprofen.', 'allergens': 'Advil may cause a severe allergic reaction, especially in individuals who are allergic to aspirin. Symptoms of an allergic reaction can include hives, facial swelling, and asthma.', 'harmful_ingredients': 'Ibuprofen, the active ingredient in Advil, can cause side effects such as stomach bleeding, ulcers, and kidney damage if used excessively or inappropriately. It is important to follow the recommended dosage and consult a healthcare provider if you have any pre-existing conditions or are taking other medications.', 'conclusion': 'Advil, containing Ibuprofen as its active ingredient, is effective for pain relief but carries potential risks, especially for individuals with aspirin allergies or those who misuse the medication. It is crucial to adhere to the recommended dosage and be aware of any allergic reactions or side effects.', 'sources': '- https://www.advil.com/our-products/advil-pain/advil-tablets/\n- https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=1a665e64-9f30-be37-4a83-38789f1f1e89\n- https://labeling.pfizer.com/ShowLabeling.aspx?id=2580\n- https://www.accessdata.fda.gov/drugsatfda_docs/label/2017/020402s042lbl.pdf'})
#
# Ingredients
# ------------
# The primary active ingredient in Advil is Ibuprofen, which is a nonsteroidal anti-inflammatory drug (NSAID). Each tablet contains 200 mg of Ibuprofen.
#
#
# harmful_ingredients
# --------------
# Ibuprofen, the active ingredient in Advil, can cause side effects such as stomach bleeding, ulcers, and kidney damage if used excessively or inappropriately. It is important to follow the recommended dosage and consult a healthcare provider if you have any pre-existing conditions or are taking other medications.
#
#
# Allergens
# ------
# Advil may cause a severe allergic reaction, especially in individuals who are allergic to aspirin. Symptoms of an allergic reaction can include hives, facial swelling, and asthma.
#
#
# Conclusion
# -------
# Advil, containing Ibuprofen as its active ingredient, is effective for pain relief but carries potential risks, especially for individuals with aspirin allergies or those who misuse the medication. It is crucial to adhere to the recommended dosage and be aware of any allergic reactions or side effects.
#
#
# SOURCES
# -------
# - https://www.advil.com/our-products/advil-pain/advil-tablets/
# - https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=1a665e64-9f30-be37-4a83-38789f1f1e89
# - https://labeling.pfizer.com/ShowLabeling.aspx?id=2580
# - https://www.accessdata.fda.gov/drugsatfda_docs/label/2017/020402s042lbl.pdf

# %%
out = runnable.invoke({
    "input": "I want to know about 'MnM'",
    "chat_history": [],
})
print(build_report(
    output=out["intermediate_steps"][-1].tool_input
))
# Out:
# run_oracle
# intermediate_steps: []
# run_tool
# product_search.invoke(input={'query': 'MnM product ingredients'})
# run_oracle
# intermediate_steps: [AgentAction(tool='product_search', tool_input={'query': 'MnM product ingredients'}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 'MnM product ingredients'}, log="Ingredients Nutrition Information | M&M'S\nIngredients: sugar, cocoa mass, skimmed milk powder, cocoa butter, lactose, starch, milk fat, palm fat, glucose syrup, shea fat, stabiliser (gum arabic) ...\nhttps://www.mms.com/en-ch/nutrition-information\n---\nIngredient and Nutritional Information: M&M'S® Milk ...\nIngredient Declaration:\u200b\u200b MILK CHOCOLATE (SUGAR, COCOA BUTTER, SKIM MILK, CHOCOLATE, MILKFAT, LACTOSE, SOY LECITHIN, ARTIFICIAL FLAVOR).\nhttps://www.webstaurantstore.com/documents/nutrition/mars_full_size_milk_chocolate_candy_bar_variety_pack_nutrition_information.pdf?srsltid=AfmBOorIEEmQmWDFUdVowzGDynRnikG_ueCCFweGlJqaQGM_1RltlNgz\n---\nM&M'S® Milk Chocolate Candies\nMilk Chocolate (Sugar, Chocolate, Cocoa Butter, Skim Milk, Milkfat, Lactose, Soy Lecithin, Salt, Artificial Flavors), Sugar, Cornstarch, less than 1% - Corn ...\nhttps://www.marsfoodservices.com/product/mms-brand-milk-chocolate-candies\n---\nEWG's Food Scores | M&m's Peanut Chocolate Candies ...\nThis product contains the following ingredient(s) that may be genetically engineered or derived from GE crops: Corn Starch, Corn Syrup, Sugars, and Lecithin ( ...\nhttps://www.ewg.org/foodscores/products/040000544982-MmsPeanutChocolateCandiesPeanut/\n---\nM&M's Milk Chocolate Candies\nIngredients. Milk Chocolate (Sugar, Chocolate, Skim Milk, Cocoa Butter, Lactose, Milkfat, Soy Lecithin, Salt, Artificial Flavors), Sugar, Cornstarch, ...\nhttps://www.heb.com/product-detail/m-m-s-milk-chocolate-candies/1533493")]
# run_tool
# product_search.invoke(input={'query': 'M&M allergens'})
# run_oracle
# intermediate_steps: [AgentAction(tool='product_search', tool_input={'query': 'MnM product ingredients'}, log='TBD'), AgentAction(tool='product_search', tool_input={'query': 
# run_tool
# final_answer.invoke(input={'ingredients': 'Milk Chocolate (Sugar, Chocolate, Cocoa Butter, Skim Milk, Milkfat, Lactose, Soy Lecithin, Salt, Artificial Flavors), Sugar, Cornstarch, less than 1% - Corn Syrup, Dextrin, Coloring (includes Blue 1 Lake, Yellow 6, Red 40, Yellow 5, Blue 1, Red 40 Lake, Yellow 6 Lake, Yellow 5 Lake, Blue 2 Lake, Blue 2), Gum Acacia.', 'allergens': 'Contains milk and soy. May contain peanuts, tree nuts (such as almonds and hazelnuts).', 'harmful_ingredients': 'Artificial Flavors: These can sometimes cause allergic reactions or sensitivities in some individuals. Artificial colors (such as Red 40, Yellow 5, and Yellow 6) have been associated with hyperactivity in children and other health concerns in sensitive individuals.', 'conclusion': "M&M's are a popular candy made primarily of milk chocolate and sugar, with a colorful candy shell. They contain common allergens such as milk and soy, and may also contain traces of peanuts and tree nuts. While generally safe for most people, the artificial flavors and colors used in M&M's can cause reactions in sensitive individuals. Consumers with allergies or sensitivities should be cautious when consuming this product.", 'sources': '- https://www.mms.com/en-ch/nutrition-information\n- https://www.webstaurantstore.com/documents/nutrition/mars_full_size_milk_chocolate_candy_bar_variety_pack_nutrition_information.pdf\n- https://www.marsfoodservices.com/product/mms-brand-milk-chocolate-candies\n- https://chocoholicbouquet.com/pages/m-ms-ingredients-allergens'})
#
# Ingredients
# ------------
# Milk Chocolate (Sugar, Chocolate, Cocoa Butter, Skim Milk, Milkfat, Lactose, Soy Lecithin, Salt, Artificial Flavors), Sugar, Cornstarch, less than 1% - Corn Syrup, Dextrin, Coloring (includes Blue 1 Lake, Yellow 6, Red 40, Yellow 5, Blue 1, Red 40 Lake, Yellow 6 Lake, Yellow 5 Lake, Blue 2 Lake, Blue 2), Gum Acacia.
#
#
# harmful_ingredients
# --------------
# Artificial Flavors: These can sometimes cause allergic reactions or sensitivities in some individuals. Artificial colors (such as Red 40, Yellow 5, and Yellow 6) have been associated with hyperactivity in children and other health concerns in sensitive individuals.
#
#
# Allergens
# ------
# Contains milk and soy. May contain peanuts, tree nuts (such as almonds and hazelnuts).
#
#
# Conclusion
# -------
# M&M's are a popular candy made primarily of milk chocolate and sugar, with a colorful candy shell. They contain common allergens such as milk and soy, and may also contain traces of peanuts and tree nuts. While generally safe for most people, the artificial flavors and colors used in M&M's can cause reactions in sensitive individuals. Consumers with allergies or sensitivities should be cautious when consuming this product.
#
#
# SOURCES
# -------
# - https://www.mms.com/en-ch/nutrition-information
# - https://www.webstaurantstore.com/documents/nutrition/mars_full_size_milk_chocolate_candy_bar_variety_pack_nutrition_information.pdf
# - https://www.marsfoodservices.com/product/mms-brand-milk-chocolate-candies
# - https://chocoholicbouquet.com/pages/m-ms-ingredients-allergens
